# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Feature Engineering

# %% [markdown]
# ### 1.1. Exploratory Data Analysis

# %%
# Read preprocessed dataset
df = pd.read_csv("preprocessed_cars.csv")
df.drop("Unnamed: 0", axis=1, inplace=True)
df.head()
# Out:
#    name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0    20  2014         450000     145500     0            1             1
# 1    26  2014         370000     120000     0            1             1
# 2    10  2006         158000     140000     1            1             1
# 3    11  2010         225000     127000     0            1             1
# 4    20  2007         130000     120000     1            1             1
#
#    owner  mileage  engine  max_power  seats
# 0      1    23.40  1248.0      74.00    5.0
# 1      2    21.14  1498.0     103.52    5.0
# 2      3    17.70  1497.0      78.00    5.0
# 3      1    23.00  1396.0      90.00    5.0
# 4      1    16.10  1298.0      88.20    5.0

# %%
sns.kdeplot(data=df, x="selling_price")
# Out:
# <Axes: xlabel='selling_price', ylabel='Density'>

# %%
# Putting the price in a bucket of 0, 1, 2, 3
labels = [0, 1, 2, 3]

# Data is a bit screwed to the right so it is best to use quartiles cut
df["price_category"] = pd.qcut(df.selling_price, q=len(labels), labels=labels).astype(int)
sns.countplot(data=df, x="price_category")
# Out:
# <Axes: xlabel='price_category', ylabel='count'>

# %%
sns.boxplot(x = df.price_category, y = df.selling_price);
plt.ylabel("Selling Price")
plt.xlabel("Price Category")
# Out:
# Text(0.5, 0, 'Price Category')

# %% [markdown]
# ### 1.2. One Hot Encoding

# %%
# Feature Selection
X = df[['year', 'transmission', 'engine', 'max_power']]
y = df.price_category

# One Hot Encoding function
one_hot_encode = lambda arr: np.eye(4)[arr]
y_encoded = one_hot_encode(y)

print("Sample 1 label: ", y[1])
print("Sample 1 label encoding: ", y_encoded[1])
# Out:
# Sample 1 label:  1
# Sample 1 label encoding:  [0. 1. 0. 0.]

# %% [markdown]
# ### 1.3. Train Test Split

# %%
from sklearn.model_selection import train_test_split

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size = 0.3, random_state = 102)

# %% [markdown]
# ### 1.4. Scale Features

# %%
from sklearn.preprocessing import StandardScaler

# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
import pickle

# Save Scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# add intercept to our X
intercept = np.ones((X_train.shape[0], 1))
X_train   = np.concatenate((intercept, X_train), axis=1)  #add intercept
intercept = np.ones((X_test.shape[0], 1))
X_test    = np.concatenate((intercept, X_test), axis=1)  #add intercept

# %% [markdown]
# ## 2. Modelling

# %%
# Experiment tracking
import mlflow
import os

mlflow.set_tracking_uri("https://admin:password@mlflow.ml.brain.cs.ait.ac.th")
# Set log name
os.environ["LOGNAME"] = "st124956"
# Create mlflow experiment
mlflow.set_experiment(experiment_name="st124956-a3")
# Out:
# 2025/03/14 13:54:20 INFO mlflow.tracking.fluent: Experiment with name 'st124956-a3' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/335598606980364929', creation_time=1741960876389, experiment_id='335598606980364929', last_update_time=1741960876389, lifecycle_stage='active', name='st124956-a3', tags={}>

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from mlflow.models.signature import infer_signature

class LogisticRegression:
    
    def __init__(self, k, n, method, run_id, alpha=0.001, max_iter=5000, lambda_=0.0, use_l2=False):
        self.k = k
        self.n = n
        self.alpha = alpha
        self.max_iter = max_iter
        self.method = method
        self.lambda_ = lambda_
        self.use_l2 = use_l2
        self.run_id = run_id
    
    def fit(self, X, Y):
        self.W = np.random.rand(self.n, self.k)
        self.losses = []
        
        if self.method == "batch":
            start_time = time.time()
            for i in range(self.max_iter):
                loss, grad =  self.gradient(X, Y)
                self.losses.append(loss)
                self.W = self.W - self.alpha * grad
            print(f"Time taken: {time.time() - start_time:.2f} sec")
            
        elif self.method == "minibatch":
            start_time = time.time()
            batch_size = int(0.3 * X.shape[0])
            for i in range(self.max_iter):
                ix = np.random.randint(0, X.shape[0] - batch_size + 1)  # Avoid out-of-bounds error
                batch_X = X[ix:ix + batch_size]
                batch_Y = Y[ix:ix + batch_size]
                loss, grad = self.gradient(batch_X, batch_Y)
                self.losses.append(loss)
                self.W = self.W - self.alpha * grad
            print(f"Time taken: {time.time() - start_time:.2f} sec")
            
        elif self.method == "sto":
            start_time = time.time()
            for i in range(self.max_iter):
                idx = np.random.randint(X.shape[0])
                X_train = X[idx, :].reshape(1, -1)
                Y_train = Y[idx].reshape(1, -1)
                loss, grad = self.gradient(X_train, Y_train)
                self.losses.append(loss)
                self.W = self.W - self.alpha * grad
            print(f"Time taken: {time.time() - start_time:.2f} sec")
            
        else:
            raise ValueError('Method must be one of the followings: "batch", "minibatch" or "sto".')
        
    def gradient(self, X, Y):
        """
        Compute loss and gradient with optional Ridge (L2) Regularization.
        """
        m = X.shape[0]
        h = self.h_theta(X, self.W)
        loss = - np.sum(Y * np.log(h)) / m
        
        # If L2 regularization is enabled, add Ridge penalty
        if self.use_l2:
            loss += self.lambda_ * np.sum(self.W ** 2) / 2
        
        error = h - Y
        grad = self.softmax_grad(X, error)
        
        # Add L2 regularization term to the gradient if enabled
        if self.use_l2:
            grad += self.lambda_ * self.W  
        
        return loss, grad

    def softmax(self, theta_t_x):
        return np.exp(theta_t_x) / np.sum(np.exp(theta_t_x), axis=1, keepdims=True)

    def softmax_grad(self, X, error):
        return X.T @ error

    def h_theta(self, X, W):
        return self.softmax(X @ W)
    
    def predict(self, X_test):
        return np.argmax(self.h_theta(X_test, self.W), axis=1)
    
    def plot(self):
        plt.plot(np.arange(len(self.losses)), self.losses, label="Train Losses")
        plt.title("Losses Over Iterations")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.show()
    
    def accuracy(self, y_true, y_pred):
        """
        Compute accuracy as correct predictions / all predictions.
        """
        return np.sum(y_true == y_pred) / len(y_true)

    def precision(self, y_true, y_pred, class_label):
        """
        Compute precision for a specific class.
        Precision_c = TP_c / (TP_c + FP_c)
        """
        cm = confusion_matrix(y_true, y_pred)
        TP = cm[class_label, class_label]
        FP = np.sum(cm[:, class_label]) - TP  # False Positives
        return TP / (TP + FP) if (TP + FP) > 0 else 0

    def recall(self, y_true, y_pred, class_label):
        """
        Compute recall for a specific class.
        Recall_c = TP_c / (TP_c + FN_c)
        """
        cm = confusion_matrix(y_true, y_pred)
        TP = cm[class_label, class_label]
        FN = np.sum(cm[class_label, :]) - TP  # False Negatives
        return TP / (TP + FN) if (TP + FN) > 0 else 0

    def f1_score(self, y_true, y_pred, class_label):
        """
        Compute F1-score for a specific class.
        F1_c = 2 * (precision_c * recall_c) / (precision_c + recall_c)
        """
        prec = self.precision(y_true, y_pred, class_label)
        rec = self.recall(y_true, y_pred, class_label)
        return 2 * (prec * rec) / (prec + rec) if (prec + rec) > 0 else 0

    ## NEW FUNCTIONS (Macro & Weighted Metrics)
    
    def macro_precision(self, y_true, y_pred):
        classes = np.unique(y_true)
        return np.mean([self.precision(y_true, y_pred, c) for c in classes])

    def macro_recall(self, y_true, y_pred):
        classes = np.unique(y_true)
        return np.mean([self.recall(y_true, y_pred, c) for c in classes])

    def macro_f1(self, y_true, y_pred):
        classes = np.unique(y_true)
        return np.mean([self.f1_score(y_true, y_pred, c) for c in classes])

    def weighted_precision(self, y_true, y_pred):
        classes, counts = np.unique(y_true, return_counts=True)
        total_samples = len(y_true)
        return sum((counts[c] / total_samples) * self.precision(y_true, y_pred, c) for c in classes)

    def weighted_recall(self, y_true, y_pred):
        classes, counts = np.unique(y_true, return_counts=True)
        total_samples = len(y_true)
        return sum((counts[c] / total_samples) * self.recall(y_true, y_pred, c) for c in classes)

    def weighted_f1(self, y_true, y_pred):
        classes, counts = np.unique(y_true, return_counts=True)
        total_samples = len(y_true)
        return sum((counts[c] / total_samples) * self.f1_score(y_true, y_pred, c) for c in classes)

    def classification_report(self, y_true, y_pred):
        """
        Generate a classification report similar to sklearn's classification_report.
        """
        classes = np.unique(y_true)
        report = f"{'Class':<10}{'Precision':<12}{'Recall':<12}{'F1-Score':<12}\n"
        report += "-" * 50 + "\n"

        for c in classes:
            prec = self.precision(y_true, y_pred, c)
            rec = self.recall(y_true, y_pred, c)
            f1 = self.f1_score(y_true, y_pred, c)
            report += f"{c:<10}{prec:<12.4f}{rec:<12.4f}{f1:<12.4f}\n"

        # Macro and Weighted Averages
        macro_prec = self.macro_precision(y_true, y_pred)
        macro_rec = self.macro_recall(y_true, y_pred)
        macro_f1 = self.macro_f1(y_true, y_pred)

        weighted_prec = self.weighted_precision(y_true, y_pred)
        weighted_rec = self.weighted_recall(y_true, y_pred)
        weighted_f1 = self.weighted_f1(y_true, y_pred)

        report += "-" * 50 + "\n"
        report += f"{'Macro Avg':<10}{macro_prec:<12.4f}{macro_rec:<12.4f}{macro_f1:<12.4f}\n"
        report += f"{'Weighted Avg':<10}{weighted_prec:<12.4f}{weighted_rec:<12.4f}{weighted_f1:<12.4f}\n"

        return report

    def cross_validate(self, X, Y, k_folds=5):
        """
        Perform K-Fold Cross-Validation and log each fold separately in MLflow.
        Logs all key metrics (accuracy, precision, recall, F1-score).
        """
        kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

        for fold, (train_index, val_index) in enumerate(kf.split(X), start=1):
            X_train, X_val = X[train_index], X[val_index]
            Y_train, Y_val = Y[train_index], Y[val_index]

            with mlflow.start_run(run_name=f"Run: {self.run_id}, Fold: {fold}"):
                mlflow.log_param("method", self.method)
                mlflow.log_param("alpha", self.alpha)
                mlflow.log_param("use_l2", self.use_l2)
                mlflow.log_param("lambda_", self.lambda_)
                mlflow.log_param("fold", fold)
                mlflow.log_param("max_iter", self.max_iter)

                # Reset and train model
                self.W = np.random.rand(self.n, self.k)
                self.fit(X_train, Y_train)

                y_pred = self.predict(X_val)
                Y_val_labels = np.argmax(Y_val, axis=1)

                # Compute metrics
                accuracy = self.accuracy(Y_val_labels, y_pred)

                macro_prec = self.macro_precision(Y_val_labels, y_pred)
                macro_rec = self.macro_recall(Y_val_labels, y_pred)
                macro_f1 = self.macro_f1(Y_val_labels, y_pred)
                
                weighted_prec = self.weighted_precision(Y_val_labels, y_pred)
                weighted_rec = self.weighted_recall(Y_val_labels, y_pred)
                weighted_f1 = self.weighted_f1(Y_val_labels, y_pred)

                print(f"Fold {fold} accuracy: ", accuracy)

                # Log metrics in MLflow
                mlflow.log_metric("accuracy", accuracy)
                mlflow.log_metric("macro_precision", macro_prec)
                mlflow.log_metric("macro_recall", macro_rec)
                mlflow.log_metric("macro_f1", macro_f1)
                mlflow.log_metric("weighted_precision", weighted_prec)
                mlflow.log_metric("weighted_recall", weighted_rec)
                mlflow.log_metric("weighted_f1", weighted_f1)

                # Log model with input example and inferred signature
                input_example = np.array([X_val[0]])  # Single example input
                signature = infer_signature(X_val, y_pred)  # Infer signature from input-output
                mlflow.sklearn.log_model(self, f"model_fold_{fold}", input_example=input_example, signature=signature)

# %% [markdown]
# ### 2.1. Train the Model

# %%
# Initialize and Train Model with Cross-Validation & MLflow Tracking
k = len(labels)
n = X_train.shape[1]

# Define multiple values for each parameter
methods = ["batch", "minibatch", "sto"]
alphas = [0.001, 0.005, 0.01]
lambdas = [0.1, 0.05, 0.01]
use_l2_options = [True, False]

run_id = 1

for method in methods:
    for alpha in alphas:
        for lambda_ in lambdas:
            for use_l2 in use_l2_options:
                model = LogisticRegression(k=k, n=n, method=method, alpha=alpha, lambda_=lambda_, use_l2=use_l2, run_id=run_id)
                model.cross_validate(X_train, y_train, k_folds=5)

                run_id += 1
# Out:
# Time taken: 1.41 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 1, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/4aeb896e054e466c8d98ee86d5ea3134
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.45 sec
# Fold 2 accuracy:  0.6828153564899452
# 🏃 View run Run: 1, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/2bc3ed182bea460b936e84644f16f3b9
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.58 sec
# Fold 3 accuracy:  0.6727605118829981
# 🏃 View run Run: 1, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/649e30fb98db4a5481ecf9b01c2a80f4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.55 sec
# Fold 4 accuracy:  0.6727605118829981
# 🏃 View run Run: 1, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/4463c973391a4c7f92d58fc446fba275
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.64 sec
# Fold 5 accuracy:  0.6413540713632205
# 🏃 View run Run: 1, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/1be1f18d9eab4f27ae595941011bfc6b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.80 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 2, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/a24754a1cb9348e990940575ba24bb53
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.78 sec
# Fold 2 accuracy:  0.6828153564899452
# 🏃 View run Run: 2, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/d9bb45ec40974a44bd7067719c10ba50
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.71 sec
# Fold 3 accuracy:  0.6727605118829981
# 🏃 View run Run: 2, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/21c5ad2f0b354920a22f7a0d760c4224
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.64 sec
# Fold 4 accuracy:  0.6727605118829981
# 🏃 View run Run: 2, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/c44ec583d0084b0a891dda5b7a98d93c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.41 sec
# Fold 5 accuracy:  0.6413540713632205
# 🏃 View run Run: 2, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/4ffa49d98d8e4727992b49c113a8af8c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.81 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 3, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/902c0a8fd83244509524eb4cb22ded08
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.66 sec
# Fold 2 accuracy:  0.6828153564899452
# 🏃 View run Run: 3, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/9a5b278c3a854f1fbc0d9fe591df11b1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.69 sec
# Fold 3 accuracy:  0.6727605118829981
# 🏃 View run Run: 3, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/0192e6e9ca6f44299e70ad8f777ea262
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.50 sec
# Fold 4 accuracy:  0.6727605118829981
# 🏃 View run Run: 3, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/8200cac370c94070aa7a5ff225ee0729
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.76 sec
# Fold 5 accuracy:  0.6413540713632205
# 🏃 View run Run: 3, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/28bf3b5c31714ea1851561c2312529d3
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.65 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 4, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6dbf2cb093994d12a7cbd214c520505f
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.43 sec
# Fold 2 accuracy:  0.6828153564899452
# 🏃 View run Run: 4, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/0f98fb277d56492aa4f892306a94b902
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.78 sec
# Fold 3 accuracy:  0.6727605118829981
# 🏃 View run Run: 4, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/620ff12bb7d04e8ba8508ffd121ca579
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.73 sec
# Fold 4 accuracy:  0.6727605118829981
# 🏃 View run Run: 4, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/66b920a148da4024845575fdb6d81b5a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.85 sec
# Fold 5 accuracy:  0.6413540713632205
# 🏃 View run Run: 4, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/24eb42a7cc594bf8aa5780956402fbc0
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.70 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 5, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/c4d1151af864457f8258d5e255bd9f6a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.83 sec
# Fold 2 accuracy:  0.6828153564899452
# 🏃 View run Run: 5, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f1d63eed89ad4218b7d132472c24ecef
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.81 sec
# Fold 3 accuracy:  0.6727605118829981
# 🏃 View run Run: 5, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/16a891bddebb4f9bb9d850da68beee68
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.77 sec
# Fold 4 accuracy:  0.6727605118829981
# 🏃 View run Run: 5, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/1ee1cabebf8244dfb86036183a56af73
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.22 sec
# Fold 5 accuracy:  0.6413540713632205
# 🏃 View run Run: 5, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/79ea8c259b2743778019f791a0000353
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.75 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 6, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fb4b39266c294ca188ae47fa1c488952
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.74 sec
# Fold 2 accuracy:  0.6828153564899452
# 🏃 View run Run: 6, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/40d10859572848149ee0eea9bbec3621
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.79 sec
# Fold 3 accuracy:  0.6727605118829981
# 🏃 View run Run: 6, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/9ac955caa6e141c381e7916679f1065b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.81 sec
# Fold 4 accuracy:  0.6727605118829981
# 🏃 View run Run: 6, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e47727f52a764e62a5ea40dbdcea51c8
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.75 sec
# Fold 5 accuracy:  0.6413540713632205
# 🏃 View run Run: 6, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/11a5e880fc96467d99268cffcbcdfc6b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.82 sec
# Fold 1 accuracy:  0.6087751371115173
# 🏃 View run Run: 7, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/b8dcdb8c882343b79aebfe4c4cf372c8
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.75 sec
# Fold 2 accuracy:  0.5950639853747715
# 🏃 View run Run: 7, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/340b6d9c92fd4827897f10178398d2d0
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.83 sec
# Fold 3 accuracy:  0.6261425959780622
# 🏃 View run Run: 7, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f3df4fde35644e5c81ca2f95eb81c04b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.91 sec
# Fold 4 accuracy:  0.573126142595978
# 🏃 View run Run: 7, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f6c4ac3454da4e29bc3927ca3ea78ad6
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.05 sec
# Fold 5 accuracy:  0.5699908508691675
# 🏃 View run Run: 7, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/3b7d099fd5294f8b801dcf347b14b830
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.75 sec
# Fold 1 accuracy:  0.5146252285191956
# 🏃 View run Run: 8, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/ac5d67c9ed3547fda8e8db6aaa7b9fd4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.94 sec
# Fold 2 accuracy:  0.6014625228519196
# 🏃 View run Run: 8, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/1bc9d4279bc642e7a87b94ee068170c1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.86 sec
# Fold 3 accuracy:  0.5904936014625228
# 🏃 View run Run: 8, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f5a03b7839de488887b4d67c22c54b7d
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.93 sec
# Fold 4 accuracy:  0.5100548446069469
# 🏃 View run Run: 8, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/8ed5ae0863d2494fa9d5aa1859f68853
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.81 sec
# Fold 5 accuracy:  0.5699908508691675
# 🏃 View run Run: 8, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/8757bc4392a14247ae3062080d56149f
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.82 sec
# Fold 1 accuracy:  0.5146252285191956
# 🏃 View run Run: 9, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/c972a5c1520a40c4bb695412c21fd683
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.85 sec
# Fold 2 accuracy:  0.5950639853747715
# 🏃 View run Run: 9, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/02adfdcaf19b4842aa9b262e4b761321
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.84 sec
# Fold 3 accuracy:  0.5137111517367459
# 🏃 View run Run: 9, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/169f0a37457a478a92360dca466f3a7f
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.64 sec
# Fold 4 accuracy:  0.5722120658135283
# 🏃 View run Run: 9, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/23e59f0da65d47c9a3e35fc7873e7a96
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.94 sec
# Fold 5 accuracy:  0.515096065873742
# 🏃 View run Run: 9, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/5c31ff05035443589d338028159ebbd6
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.70 sec
# Fold 1 accuracy:  0.5146252285191956
# 🏃 View run Run: 10, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/cb3d7cb86f2f44a89a038c7bc378d879
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.91 sec
# Fold 2 accuracy:  0.6014625228519196
# 🏃 View run Run: 10, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/01d7ef7fbfcd4a3fbce929076d52f9f4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.87 sec
# Fold 3 accuracy:  0.5685557586837294
# 🏃 View run Run: 10, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/1522c076344942839febcc90634e6cad
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.85 sec
# Fold 4 accuracy:  0.5859232175502742
# 🏃 View run Run: 10, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/46fc0e4a8b414ca0b42ad2b2b877266d
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.85 sec
# Fold 5 accuracy:  0.5699908508691675
# 🏃 View run Run: 10, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/83d3fae380ba41e69d414755a6dc237e
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.87 sec
# Fold 1 accuracy:  0.6087751371115173
# 🏃 View run Run: 11, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/3712a1df451c4b249942ef7d8fbe2c58
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.88 sec
# Fold 2 accuracy:  0.5941499085923218
# 🏃 View run Run: 11, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/ec576b56d26a4090a81833395d0d30fc
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.82 sec
# Fold 3 accuracy:  0.5786106032906764
# 🏃 View run Run: 11, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/2d5dbfef6e7c4f05bf782a5b515325d7
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.97 sec
# Fold 4 accuracy:  0.593235831809872
# 🏃 View run Run: 11, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6b3944fb23d14c5eb59be8bab03b4af0
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.00 sec
# Fold 5 accuracy:  0.5718206770356816
# 🏃 View run Run: 11, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/db9d567fc2144379aab40f2138a2bf5c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.94 sec
# Fold 1 accuracy:  0.5146252285191956
# 🏃 View run Run: 12, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fea4c47d89774ca897884fa2ccd4d30f
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.72 sec
# Fold 2 accuracy:  0.6014625228519196
# 🏃 View run Run: 12, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/983e3cbd7d6a497f9cb5221da257b109
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.79 sec
# Fold 3 accuracy:  0.5301645338208409
# 🏃 View run Run: 12, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/2804ac1e3e924f9fadac27725b68c067
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.81 sec
# Fold 4 accuracy:  0.5722120658135283
# 🏃 View run Run: 12, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/3a440062e8264b998470ba9f56f7b450
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.88 sec
# Fold 5 accuracy:  0.5242451967063129
# 🏃 View run Run: 12, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e216f4e448f649efa2f533f66a311ae0
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.94 sec
# Fold 1 accuracy:  0.5996343692870201
# 🏃 View run Run: 13, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/30fdeb7dad654314a582ca43373777de
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.81 sec
# Fold 2 accuracy:  0.5978062157221207
# 🏃 View run Run: 13, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/d71e446bc294492ebc059e32485a6d32
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.98 sec
# Fold 3 accuracy:  0.5283363802559415
# 🏃 View run Run: 13, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/a34c89af4c964437a5910137b188570b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.83 sec
# Fold 4 accuracy:  0.5850091407678245
# 🏃 View run Run: 13, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/9ae58e3f65824f0fa78df1dccd722fe4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.91 sec
# Fold 5 accuracy:  0.5599268069533394
# 🏃 View run Run: 13, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/25accb61438048c4b053c76aa864d6e1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.71 sec
# Fold 1 accuracy:  0.5904936014625228
# 🏃 View run Run: 14, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/5a55c30bc927464a8d351a0f3df5c611
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.89 sec
# Fold 2 accuracy:  0.5091407678244972
# 🏃 View run Run: 14, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/288fb2c28b2a4d61894f2cd7437727e0
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.77 sec
# Fold 3 accuracy:  0.5383912248628885
# 🏃 View run Run: 14, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/badf44604b78433cb775a61d25eabc19
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.93 sec
# Fold 4 accuracy:  0.5575868372943327
# 🏃 View run Run: 14, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/cb804223b9ea43c6a2f1c50e4f974834
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.90 sec
# Fold 5 accuracy:  0.5580969807868252
# 🏃 View run Run: 14, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/46d830b282a445589e4bd07b99d5c88d
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.85 sec
# Fold 1 accuracy:  0.6042047531992687
# 🏃 View run Run: 15, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/daa7a6c6855e4d75817d2a1d2fa08c80
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.14 sec
# Fold 2 accuracy:  0.546617915904936
# 🏃 View run Run: 15, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/b6dc01838e884d9f8bf69fd4f70d5e4f
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.91 sec
# Fold 3 accuracy:  0.5521023765996343
# 🏃 View run Run: 15, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/013e1ac6afbe4a73bf02a0603cb12d34
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.84 sec
# Fold 4 accuracy:  0.5329067641681902
# 🏃 View run Run: 15, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/b83bace975074d1b913aa64ca086265d
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.76 sec
# Fold 5 accuracy:  0.5709057639524245
# 🏃 View run Run: 15, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e704e74241294c4d8344ad648b23098e
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.71 sec
# Fold 1 accuracy:  0.5941499085923218
# 🏃 View run Run: 16, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/ec6d0057ecb74678b999f8552004b1c6
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.85 sec
# Fold 2 accuracy:  0.6069469835466179
# 🏃 View run Run: 16, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/bce6281248784a0ab2adf85af07d04aa
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.77 sec
# Fold 3 accuracy:  0.5658135283363802
# 🏃 View run Run: 16, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fac16869c8f44f398dbce417bcd8643d
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.91 sec
# Fold 4 accuracy:  0.5557586837294333
# 🏃 View run Run: 16, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e38ecb9e43a04d94954c006c6effc9ca
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.80 sec
# Fold 5 accuracy:  0.5242451967063129
# 🏃 View run Run: 16, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/7bbc9fbc90f94947aba28de0a7dd5d98
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.84 sec
# Fold 1 accuracy:  0.6014625228519196
# 🏃 View run Run: 17, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e0c8facf03bc43b78f3c20b65ae8040b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.67 sec
# Fold 2 accuracy:  0.4954296160877514
# 🏃 View run Run: 17, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/31f892aadbaf4d0bb9b4a3d30bf20ba5
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.81 sec
# Fold 3 accuracy:  0.5740402193784278
# 🏃 View run Run: 17, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/81b3d9f62c6c49f68c9672d7f5b194c8
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.11 sec
# Fold 4 accuracy:  0.546617915904936
# 🏃 View run Run: 17, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/777abd2ade96405e9f32e1dcc86d2f64
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.73 sec
# Fold 5 accuracy:  0.5452881976212259
# 🏃 View run Run: 17, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/cdb856fec0cc43dd813656312b5b1bf8
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.03 sec
# Fold 1 accuracy:  0.5621572212065814
# 🏃 View run Run: 18, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/32960d40653b46e1a055d7af22b298d1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.96 sec
# Fold 2 accuracy:  0.5904936014625228
# 🏃 View run Run: 18, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f316e68d042d4dde9d37511a95f7083c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.65 sec
# Fold 3 accuracy:  0.5411334552102377
# 🏃 View run Run: 18, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/0f2e4da42b1343e48f670790623f1441
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 2.12 sec
# Fold 4 accuracy:  0.583180987202925
# 🏃 View run Run: 18, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6bd708cba5904e6ca09c16a140626c6a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 1.82 sec
# Fold 5 accuracy:  0.5452881976212259
# 🏃 View run Run: 18, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/3abb13e301f347249bf73ef3c22fc08c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.56 sec
# Fold 1 accuracy:  0.6745886654478976
# 🏃 View run Run: 19, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/8356ac9907dc4812a03ce4beebc5b62b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.55 sec
# Fold 2 accuracy:  0.6809872029250457
# 🏃 View run Run: 19, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/613dee89bab34d768d9ca6200adf5615
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 3 accuracy:  0.6691042047531993
# 🏃 View run Run: 19, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/075988d33fee41e8bfcd024966f7a5f4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.54 sec
# Fold 4 accuracy:  0.670018281535649
# 🏃 View run Run: 19, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/07a5f8ca583344e9ba57c7379430e4fd
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.80 sec
# Fold 5 accuracy:  0.6523330283623056
# 🏃 View run Run: 19, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/1de7e76d58794fc98639a2e640d6fbd3
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 1 accuracy:  0.680073126142596
# 🏃 View run Run: 20, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/28e9ca3ea94e47bb8048554f806c237a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 2 accuracy:  0.6809872029250457
# 🏃 View run Run: 20, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/dad2883ed3f04921afaf939f0a8124c3
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.81 sec
# Fold 3 accuracy:  0.6663619744058501
# 🏃 View run Run: 20, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/c15cb509c10546ceb514cc23c6acae91
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 4 accuracy:  0.6745886654478976
# 🏃 View run Run: 20, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/2d9405d1e19c4e0691032392ed98e77c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 5 accuracy:  0.6450137236962489
# 🏃 View run Run: 20, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f6a19c525b1e4b7fafaa17ec630ad126
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 1 accuracy:  0.6736745886654479
# 🏃 View run Run: 21, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/0c529b42dab444779841d72d2fb1caa4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 2 accuracy:  0.6782449725776966
# 🏃 View run Run: 21, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/55a1d96df7ec4172a5b152e88bcfe4e2
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.57 sec
# Fold 3 accuracy:  0.6718464351005484
# 🏃 View run Run: 21, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/59b8db7961704f4d9822ec65cce68cd1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.61 sec
# Fold 4 accuracy:  0.6709323583180987
# 🏃 View run Run: 21, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6f6dce10a3a041d6848c8fec3df22220
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.68 sec
# Fold 5 accuracy:  0.645928636779506
# 🏃 View run Run: 21, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fe47962b9c6643e2aacab7464b79f1d5
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.59 sec
# Fold 1 accuracy:  0.6736745886654479
# 🏃 View run Run: 22, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e0c71293d2334572a1d15c9a1844abd9
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 2 accuracy:  0.6819012797074955
# 🏃 View run Run: 22, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/bd286ba2325c40e68cad7a1c18d40cee
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 3 accuracy:  0.6718464351005484
# 🏃 View run Run: 22, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/26538426be634f6b8d7ee7ff091618bd
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 4 accuracy:  0.6736745886654479
# 🏃 View run Run: 22, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e893715245944ac4a5778931c3f4e8e3
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 5 accuracy:  0.6477584629460201
# 🏃 View run Run: 22, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/62a71a57b0774a95a850b983a41bfb2c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 23, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/bbe72bdc1327405eb4363f3a5529a591
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.61 sec
# Fold 2 accuracy:  0.6791590493601463
# 🏃 View run Run: 23, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/36ce33a6e8f74722a07f4045c8626634
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 3 accuracy:  0.6645338208409507
# 🏃 View run Run: 23, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/ce43d7737bd6426e9c30f93a39174079
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 4 accuracy:  0.6736745886654479
# 🏃 View run Run: 23, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/52c4e79a28a644d089cacb3a610941fc
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 5 accuracy:  0.6495882891125343
# 🏃 View run Run: 23, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6ddfe9e573124bcea3fe1b9092f8aac0
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 1 accuracy:  0.676416819012797
# 🏃 View run Run: 24, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/500a482b7494417aae292c912bdb005a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 2 accuracy:  0.676416819012797
# 🏃 View run Run: 24, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/a5d7719b41ad4840a606bf76a44c9816
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 3 accuracy:  0.6691042047531993
# 🏃 View run Run: 24, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/acb285885c0b41269493435ff6dbe628
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 4 accuracy:  0.676416819012797
# 🏃 View run Run: 24, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e6eeef84520c4f0f94889424a9a9ae9b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.56 sec
# Fold 5 accuracy:  0.6450137236962489
# 🏃 View run Run: 24, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/253e5d1b7d86424ca7f51e63089fbea4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 1 accuracy:  0.6636197440585009
# 🏃 View run Run: 25, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/9937dbacc16c40a185ede0e804dd543a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 2 accuracy:  0.6480804387568556
# 🏃 View run Run: 25, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fec93fb040ed42bd9af48044097cf224
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 3 accuracy:  0.6636197440585009
# 🏃 View run Run: 25, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/7c30f71062fa45bab4ed9caf781f5dd8
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 4 accuracy:  0.6316270566727605
# 🏃 View run Run: 25, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/170bc2757c5d4299bdbbc37fe389a2ae
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 5 accuracy:  0.636779505946935
# 🏃 View run Run: 25, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/3459ad87a33748ceba0c951b6b0a64b2
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 1 accuracy:  0.6819012797074955
# 🏃 View run Run: 26, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/72ba266d872f4fdc8585ca22f523e565
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 2 accuracy:  0.6480804387568556
# 🏃 View run Run: 26, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/c02713bd50f6473abb4dc67328cc9328
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 3 accuracy:  0.6691042047531993
# 🏃 View run Run: 26, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/0d5794ef2db34f1282c0c98714ec5645
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 4 accuracy:  0.6681901279707495
# 🏃 View run Run: 26, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/284fa9dc2da54ff48c5b704d89946e35
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.68 sec
# Fold 5 accuracy:  0.6312900274473925
# 🏃 View run Run: 26, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/08b0424986834f76852ddd189fad7b09
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.55 sec
# Fold 1 accuracy:  0.6663619744058501
# 🏃 View run Run: 27, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/37cc4b22428b400eb96454cfac0c4f22
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.69 sec
# Fold 2 accuracy:  0.6215722120658135
# 🏃 View run Run: 27, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/16b8d0545ae644508f6c7e61e4e3cbeb
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.63 sec
# Fold 3 accuracy:  0.6170018281535649
# 🏃 View run Run: 27, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fe09dbacc3ce43dc8c48e5158ae2ab42
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 4 accuracy:  0.629798903107861
# 🏃 View run Run: 27, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/47d1d0b4326e45bbae69bd1fd07368e5
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.59 sec
# Fold 5 accuracy:  0.6514181152790485
# 🏃 View run Run: 27, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/8cad5198c780407691c07a9c93a2e53c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.59 sec
# Fold 1 accuracy:  0.6727605118829981
# 🏃 View run Run: 28, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e514f037a6cd4ed78d3d2750d1c2a69d
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.55 sec
# Fold 2 accuracy:  0.6425959780621572
# 🏃 View run Run: 28, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/5dd9f450663d4b79b2f77b410c3a8988
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 3 accuracy:  0.6672760511882998
# 🏃 View run Run: 28, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/ff5fd9c1e6804ad089301a88f80be03b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 4 accuracy:  0.6371115173674589
# 🏃 View run Run: 28, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/2124be28534f44b9a6e80e7ebfcd8e0a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 5 accuracy:  0.6285452881976212
# 🏃 View run Run: 28, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/7f3aacbd02504f0aa214610d862b0d0e
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 1 accuracy:  0.6654478976234004
# 🏃 View run Run: 29, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6756225a3a704c8da8ba3f09f2921567
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 2 accuracy:  0.6471663619744058
# 🏃 View run Run: 29, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/b95ea359d07f4c91b4ce157f8a9fc643
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.53 sec
# Fold 3 accuracy:  0.6334552102376599
# 🏃 View run Run: 29, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/c98c258a119a438faa483a81038935e4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 4 accuracy:  0.6572212065813529
# 🏃 View run Run: 29, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/9355df520f9d45bcbd19b9729e5599b1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 5 accuracy:  0.62580054894785
# 🏃 View run Run: 29, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/955c43d8bad846239033dbbe9bfc63fb
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.50 sec
# Fold 1 accuracy:  0.6636197440585009
# 🏃 View run Run: 30, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/ca4035428bc048799645e35a601c7d20
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 2 accuracy:  0.6873857404021938
# 🏃 View run Run: 30, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/b2d9ea8dfa984a8a9b7eb7a5ac687f6d
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.51 sec
# Fold 3 accuracy:  0.649908592321755
# 🏃 View run Run: 30, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/edd3dc9aa3ee4f1d9775f341f8296b9c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 4 accuracy:  0.6645338208409507
# 🏃 View run Run: 30, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/7ee8b4371d474ab8893d49ddd1b9d95b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.52 sec
# Fold 5 accuracy:  0.6440988106129918
# 🏃 View run Run: 30, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/3eae5003d13046fd932490173fe884d5
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.58 sec
# Fold 1 accuracy:  0.5786106032906764
# ...
# Time taken: 0.10 sec
# Fold 1 accuracy:  0.6334552102376599
# 🏃 View run Run: 45, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/5f6ec1d02cb243728fb805fdba619571
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 2 accuracy:  0.6389396709323584
# 🏃 View run Run: 45, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/23d80ebc626d43c5a9fc9c6c100e070f
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 3 accuracy:  0.596892138939671
# 🏃 View run Run: 45, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fad919378672457cbfae501197cd64e6
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 4 accuracy:  0.6307129798903108
# 🏃 View run Run: 45, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/4ffa7f032b2a4332b48ec1fb5f8878be
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 5 accuracy:  0.6047575480329369
# 🏃 View run Run: 45, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/7af047dec40c47ad894a5b33c0d19445
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 1 accuracy:  0.6480804387568556
# 🏃 View run Run: 46, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/74271ec7ae344fdbada0aff970ffb1fa
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 2 accuracy:  0.6325411334552102
# 🏃 View run Run: 46, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/9e931a7f2c064940ba1b0ca56cfc0e35
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.07 sec
# Fold 3 accuracy:  0.6389396709323584
# 🏃 View run Run: 46, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/2e16e4813eb2467eb7f4c2118bc63eee
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 4 accuracy:  0.6243144424131627
# 🏃 View run Run: 46, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/ed659b3c5836401ebfd9901bbf6b5695
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 5 accuracy:  0.6239707227813358
# 🏃 View run Run: 46, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/bb53f4f25edf4c97aea80ccd6b6da176
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 1 accuracy:  0.649908592321755
# 🏃 View run Run: 47, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/2d6499c3699b4806a9f48ba65d00f50e
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 2 accuracy:  0.6279707495429616
# 🏃 View run Run: 47, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/899ca245da894b08bddf291fd2b076a2
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 3 accuracy:  0.6334552102376599
# 🏃 View run Run: 47, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e5c0c10e88eb4d1ba9828cbdeec21698
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.08 sec
# Fold 4 accuracy:  0.6398537477148081
# 🏃 View run Run: 47, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/7263b554e854497b81f1a8fb2620f69b
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 5 accuracy:  0.6276303751143641
# 🏃 View run Run: 47, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/8dfc98f9070642bfb204dddd2be27a52
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 1 accuracy:  0.659963436928702
# 🏃 View run Run: 48, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6fa44e5257444d6d8579928ebbab90bc
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 2 accuracy:  0.6462522851919561
# 🏃 View run Run: 48, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/d2fc30c1fd404aceb349c14f7abb1790
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 3 accuracy:  0.6380255941499086
# 🏃 View run Run: 48, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/702764242efd4abcb2769cb3ee079345
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 4 accuracy:  0.6645338208409507
# 🏃 View run Run: 48, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/26b99d64a514435f92189e04573922c8
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 5 accuracy:  0.6303751143641354
# 🏃 View run Run: 48, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/26c21e07b7a84b4c91adf81778871fd2
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.11 sec
# Fold 1 accuracy:  0.6398537477148081
# 🏃 View run Run: 49, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e7d7018f860a4bdeafc61e11b73de21e
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 2 accuracy:  0.6042047531992687
# 🏃 View run Run: 49, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/d756b4daabd840288fd546cf0cbda49e
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 3 accuracy:  0.5996343692870201
# 🏃 View run Run: 49, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fd3257a45b7e46d6814e954d4f188163
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 4 accuracy:  0.6243144424131627
# 🏃 View run Run: 49, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6613b104de324d93863bd60322cab491
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 5 accuracy:  0.565416285452882
# 🏃 View run Run: 49, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/69363fba5a2d4ba8b46f2830a234323e
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 1 accuracy:  0.6691042047531993
# 🏃 View run Run: 50, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/20e2e5b4cec948b7bba1a0e45d239cd1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 2 accuracy:  0.6489945155393053
# 🏃 View run Run: 50, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/b3a4ee4b85e8413bbf162f4ad43173cd
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 3 accuracy:  0.6398537477148081
# 🏃 View run Run: 50, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/6bd8e360b33940fda47f3d5a44d1a7dc
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.06 sec
# Fold 4 accuracy:  0.6627056672760512
# 🏃 View run Run: 50, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/279b8390ac024bd29981fe7b58f021fc
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 5 accuracy:  0.616651418115279
# 🏃 View run Run: 50, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/dca46bed3c6d46de8c5b33f5d863cd14
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 1 accuracy:  0.6279707495429616
# 🏃 View run Run: 51, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/42cefc4a45244aed8c451957f520a378
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 2 accuracy:  0.6389396709323584
# 🏃 View run Run: 51, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/32bcdcc0f99542039063d56fb971f5de
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.08 sec
# Fold 3 accuracy:  0.6215722120658135
# 🏃 View run Run: 51, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/507b8d78b0e84a2ebf3c4a4115f7582f
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 4 accuracy:  0.6352833638025595
# 🏃 View run Run: 51, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/9891aeba2530483b95fbd090c2a9f3e9
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 5 accuracy:  0.57548032936871
# 🏃 View run Run: 51, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f2ef787220db456a9cefa2dbe8dd2448
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 1 accuracy:  0.6572212065813529
# 🏃 View run Run: 52, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/cc744b8f0c9847b1a4cc578d8ed024d6
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 2 accuracy:  0.6581352833638026
# 🏃 View run Run: 52, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/148b7b6d821e4547ba3f4160a93b4eda
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 3 accuracy:  0.6590493601462523
# 🏃 View run Run: 52, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/5c7d1ebd41024f7cb46392c82046976a
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 4 accuracy:  0.6489945155393053
# 🏃 View run Run: 52, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/759e46bffb4e4567983d40877512d801
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 5 accuracy:  0.6422689844464776
# 🏃 View run Run: 52, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/a97cc44f97f04f85a04478f7435f3ea1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 1 accuracy:  0.6526508226691042
# 🏃 View run Run: 53, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/fac45a16ce9c4bcc817767c4933df4f1
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 2 accuracy:  0.6407678244972578
# 🏃 View run Run: 53, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/80df7db6fa004029b03e09ccc73d7cbc
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.11 sec
# Fold 3 accuracy:  0.6654478976234004
# 🏃 View run Run: 53, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/84c854a926b14d3da8e5f8caba331dff
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 4 accuracy:  0.6480804387568556
# 🏃 View run Run: 53, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/8b362af22d314757adad7b0fe77ecf67
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.10 sec
# Fold 5 accuracy:  0.62580054894785
# 🏃 View run Run: 53, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e55035c076bb483386f18f6afa1fbaf4
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 1 accuracy:  0.6471663619744058
# 🏃 View run Run: 54, Fold: 1 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/f09b8e6183bd48e4946b0563fd9a9f39
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 2 accuracy:  0.6480804387568556
# 🏃 View run Run: 54, Fold: 2 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/7c4023461e024353a390c93c3ff48261
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 3 accuracy:  0.6517367458866545
# 🏃 View run Run: 54, Fold: 3 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/e11bb2111229444e9482fe67a305e548
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 4 accuracy:  0.6563071297989032
# 🏃 View run Run: 54, Fold: 4 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/d9f2903d285f4aabbfaab8dd48a60e87
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929
# Time taken: 0.09 sec
# Fold 5 accuracy:  0.6404391582799634
# 🏃 View run Run: 54, Fold: 5 at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929/runs/aef9f6621bc846b293bbe1d5b33dd92c
# 🧪 View experiment at: https://admin:password@mlflow.ml.brain.cs.ait.ac.th/#/experiments/335598606980364929

# %% [markdown]
# ### 2.2. Find the best model run

# %%
# Load all runs from MLflow experiment
experiment_id = mlflow.get_experiment_by_name("st124956-a3").experiment_id
runs = mlflow.search_runs(experiment_ids=[experiment_id])

# Take the model with the best macro f1 score
best_run = runs.loc[runs['metrics.macro_f1'].idxmax()]
best_run_id = best_run["run_id"]
best_run
# Out:
# run_id                                            b2d9ea8dfa984a8a9b7eb7a5ac687f6d
# experiment_id                                                   335598606980364929
# status                                                                    FINISHED
# artifact_uri                     mlflow-artifacts:/335598606980364929/b2d9ea8df...
# start_time                                        2025-03-14 07:12:04.988000+00:00
# end_time                                          2025-03-14 07:12:10.888000+00:00
# metrics.macro_precision                                                   0.684276
# metrics.macro_f1                                                          0.683636
# metrics.weighted_f1                                                       0.688221
# metrics.accuracy                                                          0.687386
# metrics.weighted_recall                                                   0.687386
# metrics.weighted_precision                                                0.689143
# metrics.macro_recall                                                      0.683079
# params.alpha                                                                 0.005
# params.use_l2                                                                False
# params.method                                                            minibatch
# params.max_iter                                                               5000
# params.fold                                                                      2
# params.lambda_                                                                0.01
# tags.mlflow.source.name          /Users/luhtookyaw/anaconda3/envs/pt-env/lib/py...
# tags.mlflow.log-model.history    [{"run_id": "b2d9ea8dfa984a8a9b7eb7a5ac687f6d"...
# tags.mlflow.user                                                          st124956
# tags.mlflow.source.type                                                      LOCAL
# tags.mlflow.runName                                               Run: 30, Fold: 2
# Name: 123, dtype: object

# %% [markdown]
# ### 2.3. Register the best model

# %%
model_name = "st124956-a3-model"  # Replace <student_ID> with your actual student ID

# Register the best model
mlflow.register_model(f"runs:/{best_run_id}/model", model_name)
# Out:
# Successfully registered model 'st124956-a3-model'.
# 2025/03/14 14:36:18 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: st124956-a3-model, version 1
# Created version '1' of model 'st124956-a3-model'.
# <ModelVersion: aliases=[], creation_timestamp=1741963395026, current_stage='None', description='', last_updated_timestamp=1741963395026, name='st124956-a3-model', run_id='b2d9ea8dfa984a8a9b7eb7a5ac687f6d', run_link='', source='mlflow-artifacts:/335598606980364929/b2d9ea8dfa984a8a9b7eb7a5ac687f6d/artifacts/model', status='READY', status_message='', tags={}, user_id='', version='1'>

# %% [markdown]
# ### 2.4. Set the model to staging

# %%
# Get latest version of the registered model
client = mlflow.tracking.MlflowClient()
model_version = client.get_latest_versions(model_name, stages=["None"])[0].version

# Transition the model to staging
client.transition_model_version_stage(
    name=model_name,
    version=model_version,
    stage="Staging"
)
# Out:
# /var/folders/67/7mt9kx014mv5jcl1jr1pgnfc0000gn/T/ipykernel_3485/24913900.py:3: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   model_version = client.get_latest_versions(model_name, stages=["None"])[0].version
# /var/folders/67/7mt9kx014mv5jcl1jr1pgnfc0000gn/T/ipykernel_3485/24913900.py:6: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(
# <ModelVersion: aliases=[], creation_timestamp=1741963395026, current_stage='Staging', description='', last_updated_timestamp=1741963407574, name='st124956-a3-model', run_id='b2d9ea8dfa984a8a9b7eb7a5ac687f6d', run_link='', source='mlflow-artifacts:/335598606980364929/b2d9ea8dfa984a8a9b7eb7a5ac687f6d/artifacts/model', status='READY', status_message='', tags={}, user_id='', version='1'>

# %% [markdown]
# ## 3. Testing

# %% [markdown]
# ### 3.1. Sklearn classification report

# %%
from sklearn.metrics import classification_report

model_url = f"models:/{model_name}/{model_version}"

pyfunc_model = mlflow.pyfunc.load_model(model_uri)

y_pred = model.predict(X_test)
print(classification_report(np.argmax(y_test, axis=1), y_pred, digits=4))
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
#               precision    recall  f1-score   support
#
#            0     0.7961    0.8674    0.8302       558
#            1     0.5917    0.5605    0.5757       587
#            2     0.5493    0.5695    0.5592       597
#            3     0.7669    0.7148    0.7399       603
#
#     accuracy                         0.6755      2345
#    macro avg     0.6760    0.6780    0.6762      2345
# weighted avg     0.6746    0.6755    0.6743      2345

# %% [markdown]
# ### 3.2. Custom classification report

# %%
print(model.classification_report(np.argmax(y_test, axis=1), y_pred))
# Out:
# Class     Precision   Recall      F1-Score
# --------------------------------------------------
# 0         0.7961      0.8674      0.8302
# 1         0.5917      0.5605      0.5757
# 2         0.5493      0.5695      0.5592
# 3         0.7669      0.7148      0.7399
# --------------------------------------------------
# Macro Avg 0.6760      0.6780      0.6762
# Weighted Avg0.6746      0.6755      0.6743

# %% [markdown]
# ### 3.3. Comparison
#
# Both implementations produce nearly identical classification reports, confirming consistency in precision, recall, and F1-score across all classes. The overall accuracy is 0.6755, with macro and weighted averages closely aligned (macro F1-score: 0.6762, weighted F1-score: 0.6743). This validates that both methods effectively evaluate model performance, ensuring reliability in classification results.
